# %%
from src.connect_database import session
import pandas as pd
from sqlalchemy import create_engine



df = pd.DataFrame(session.execute('SELECT * FROM mushroom.mushrooms'))
df
# Out:
#   field_0_ bruises cap_color cap_shape cap_surface gill_attachment gill_color  \
# 0        p       f         n         k           y               f          b
# 1        e       f         n         x           s               a          y
#
#   gill_size gill_spacing habitat  ... ring_type spore_print_color  \
# 0         n            c       l  ...         e                 w
# 1         b            c       l  ...         p                 o
#
#   stalk_color_above_ring stalk_color_below_ring stalk_root stalk_shape  \
# 0                      w                      w          ?           t
# 1                      o                      o          ?           e
#
#   stalk_surface_above_ring stalk_surface_below_ring veil_color veil_type
# 0                        s                        k          w         p
# 1                        s                        s          o         p
#
# [2 rows x 23 columns]
